# %% [markdown]
# # Lesson 6 Class Exercises: More Practice

# %% [markdown]
# We will use today's class exercise to reinforce the learning we've done to this point

# %% [markdown]
# ## Get Started
# Import the Numpy and Pandas packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Read in the apple data found in the `data/apple_data.tsv` directory.

# %%
apple = pd.read_csv('data/apple_data.tsv', delimiter='\t')
apple.head(5)
# Out:
#            State    1982    1987    1992    1997    2002    2007     1982  \
# 0        Alabama    899     626     474     479     265     231    1,548
# 1         Alaska      --      --      2       4       9      10        --
# 2        Arizona    214     224     235     158     185     496    1,969
# 3       Arkansas    512     451     247     238     164     153    2,276
# 4     California  2,904   2,787   3,082   3,454   2,120   2,074   29,933
#
#       1987   1992.1   1997.1   2002.1   2007.1 2002.2 2007.2  2002.3  2007.3
# 0   1,217    1,011      968      594      393     191    144     386     307
# 1       --      (D)       2       13       15       8     10     (D)     (D)
# 2   4,881    5,770    4,003    1,581    1,344     118    424   1,459   1,249
# 3   2,120    1,430    1,048      658      287     123    116     560     220
# 4  34,105   42,024   49,704   38,268   22,184   1,850  1,850  35,856  20,954

# %% [markdown]
# Explore the data using the approach we've used thus far:
# - List all of the column names
# - Identify the data types
# - Find the shape of the data
# - Explore categorical values -- do we have the expected number of values for each?
# - Get descriptive statistics for the numerical data
# - Do we have missing values?
# - Do we have duplicates?

# %%
apple.columns
# Out:
# Index(['       State', '1982', '1987', '1992', '1997', '2002', '2007',
#        '  1982', '  1987', '1992.1', '1997.1', '2002.1', '2007.1', '2002.2',
#        '2007.2', '2002.3', '2007.3'],
#       dtype='object')

# %%
apple.dtypes
# Out:
#        State    object
# 1982            object
# 1987            object
# 1992            object
# 1997            object
# 2002            object
# 2007            object
#   1982          object
#   1987          object
# 1992.1          object
# 1997.1          object
# 2002.1          object
# 2007.1          object
# 2002.2          object
# 2007.2          object
# 2002.3          object
# 2007.3          object
# dtype: object

# %%
apple.shape
# Out:
# (50, 17)

# %%
apple["       State"].unique().shape
# Out:
# (50,)

# %%
apple.describe()
# Out:
#               State 1982 1987  1992  1997  2002 2007   1982   1987 1992.1  \
# count            50   50   50    50    50    50   50     50     50     50
# unique           50   49   48    49    49    50   49     49     49     49
# top         Alabama   --   --  392   485   265   35      --     --    (D)
# freq              1    2    2     2     2     1    2      2      2      2
#
#         1997.1 2002.1 2007.1 2002.2 2007.2 2002.3 2007.3
# count       50     50     50     50     50     50     50
# unique      48     48     48     46     49     46     48
# top     5,389     (D)    (D)      8    427    (D)    (D)
# freq         2      3      3      2      2      5      3

# %%
apple.isna().sum()
# Out:
#        State    0
# 1982            0
# 1987            0
# 1992            0
# 1997            0
# 2002            0
# 2007            0
#   1982          0
#   1987          0
# 1992.1          0
# 1997.1          0
# 2002.1          0
# 2007.1          0
# 2002.2          0
# 2007.2          0
# 2002.3          0
# 2007.3          0
# dtype: int64

# %%
apple.duplicated().sum()
# Out:
# 0

# %% [markdown]
# What needs cleaning with the data?

# %% [raw]
# Column headers need to be renamed and removed spaces, need unique names, missing values, changing objects into numbers for further analysis,

# %% [markdown]
# ### Clean the data

# %% [markdown]
# Re-read the file and make sure we have get the missing values correct.

# %%
apple = pd.read_csv('data/apple_data.tsv', delimiter='\t', na_values= ["--", "(D)"] )
apple.head(5)
# Out:
#            State    1982    1987    1992    1997    2002    2007     1982  \
# 0        Alabama    899     626     474     479     265     231    1,548
# 1         Alaska     NaN     NaN      2       4       9      10       NaN
# 2        Arizona    214     224     235     158     185     496    1,969
# 3       Arkansas    512     451     247     238     164     153    2,276
# 4     California  2,904   2,787   3,082   3,454   2,120   2,074   29,933
#
#       1987   1992.1   1997.1   2002.1   2007.1 2002.2 2007.2  2002.3  2007.3
# 0   1,217    1,011      968      594      393     191    144     386     307
# 1      NaN      NaN       2       13       15       8     10     NaN     NaN
# 2   4,881    5,770    4,003    1,581    1,344     118    424   1,459   1,249
# 3   2,120    1,430    1,048      658      287     123    116     560     220
# 4  34,105   42,024   49,704   38,268   22,184   1,850  1,850  35,856  20,954

# %% [markdown]
# Make the column names correct

# %%
apple2 = apple.set_axis(['State', '1982_Farms', '1987_Farms', '1992_Farms', '1997_Farms', '2002_Farms', '2007_Farms', '1982_TTLAcres', '1987_TTLAcres', '1992_TTLAcres', '1997_TTLAcres', '2002_TTLAcres', '2007_TTLAcres', '2002_FarmBear_Acres', '2007_FarmBear_Acres', '2002_Bear_Acres', '2007_Bear_Acres' ], axis=1)
apple2.head()
# Out:
#            State 1982_Farms 1987_Farms 1992_Farms 1997_Farms 2002_Farms  \
# 0        Alabama       899        626        474        479        265
# 1         Alaska        NaN        NaN         2          4          9
# 2        Arizona       214        224        235        158        185
# 3       Arkansas       512        451        247        238        164
# 4     California     2,904      2,787      3,082      3,454      2,120
#
#   2007_Farms 1982_TTLAcres 1987_TTLAcres 1992_TTLAcres 1997_TTLAcres  \
# 0       231         1,548         1,217         1,011           968
# 1        10            NaN           NaN           NaN            2
# 2       496         1,969         4,881         5,770         4,003
# 3       153         2,276         2,120         1,430         1,048
# 4     2,074        29,933        34,105        42,024        49,704
#
#   2002_TTLAcres 2007_TTLAcres 2002_FarmBear_Acres 2007_FarmBear_Acres  \
# 0          594           393                  191                 144
# 1           13            15                    8                  10
# 2        1,581         1,344                  118                 424
# 3          658           287                  123                 116
# 4       38,268        22,184                1,850               1,850
#
#   2002_Bear_Acres 2007_Bear_Acres
# 0             386             307
# 1             NaN             NaN
# 2           1,459           1,249
# 3             560             220
# 4          35,856          20,954

# %% [markdown]
# Next, remove commas. We need to alter the strings of multiple columns. We know how to do this within a single column, but how do we do this with multiple columns?  Remember the `apply()` function! We can apply any function we want.  We can't use the `pd.Series.str.replace()` function though because that belongs to the Pandas Series objects, we need an independent function. We can write our own!
#
# We can use the formal defintion (e.g.):
#
# ```python
# def remoteCommas(col):
#     return col.str.replace(',','')
#
# apple_data = apple_data.apply(remoteCommas)
# ```
#
# Or we can simplify it using Pythons `lambda` function definition. `lambda` is used to declare an in-line function.  It works just like a normal function but it does not have a name and is used for quick very short in-line functions.  For example:
#
# ```python
# apple_data = apple_data.apply(lambda x: x.str.replace(',',''))
# ```

# %%
apple2 = apple2.apply(lambda x: x.str.replace(',',''))

apple2
# Out:
#                 State 1982_Farms 1987_Farms 1992_Farms 1997_Farms 2002_Farms  \
# 0             Alabama       899        626        474        479        265
# 1              Alaska        NaN        NaN         2          4          9
# 2             Arizona       214        224        235        158        185
# 3            Arkansas       512        451        247        238        164
# 4          California      2904       2787       3082       3454       2120
# 5            Colorado       608        595        542        493        361
# 6         Connecticut       309        272        295        242        247
# 7            Delaware        24         18         16         18         17
# 8             Florida       196        149         92         81         53
# 9             Georgia       893        669        525        428        305
# 10             Hawaii        NaN        NaN        NaN        NaN         2
# 11              Idaho       411        377        374        342        315
# 12           Illinois       902        824        756        651        501
# 13            Indiana       792        705        685        615        442
# 14               Iowa       439        458        450        443        344
# 15             Kansas       416        318        264        261        192
# 16           Kentucky      1022        916        878        710        616
# 17          Louisiana       122        142         81         94         51
# 18              Maine       400        386        388        349        374
# 19           Maryland       551        453        392        338        288
# 20      Massachusetts       452        526        477        399        338
# 21           Michigan      2788       2516       2473       2290       1750
# 22          Minnesota       391        411        476        536        488
# 23        Mississippi       413        293        258        248        159
# 24           Missouri       871        673        539        524        485
# 25            Montana       142        145        160        148        187
# 26           Nebraska       100        124        126        106        107
# 27             Nevada        50         56         45         47         45
# 28      New Hampshire       219        209         227       210        183
# 29         New Jersey       509        563        522        485        525
# 30         New Mexico       740        666        748        806        907
# 31           New York      2055       1726       1578       1557       1447
# 32     North Carolina      1500       1186        990        949        598
# 33       North Dakota        38         29         32         28          5
# 34               Ohio      1857       1614       1454       1404       1282
# 35           Oklahoma       695        582        392        427        239
# 36             Oregon      2053       1784       1684       1763       1485
# 37       Pennsylvania      2580       2270       1854       2183       1777
# 38       Rhode Island        68         72         61         51         58
# 39     South Carolina       390        321        330        292        339
# 40       South Dakota        48         60         39         40         35
# 41          Tennessee      1321       1065        924       1003        357
# 42              Texas       845        883        782        724        596
# 43               Utah       635        568        536        485        388
# 44            Vermont       243        217        251        237        243
# 45           Virginia      1400       1160       1057        970        746
# 46         Washington      5406       5169       4596       4910       3870
# 47      West Virginia       712        586        505        593        463
# 48          Wisconsin      1027        856        965       1006        886
# 49            Wyoming        25         18         20         16         14
#
#    2007_Farms 1982_TTLAcres 1987_TTLAcres 1992_TTLAcres 1997_TTLAcres  \
# 0        231          1548          1217          1011           968
# 1         10            NaN           NaN           NaN            2
# 2        496          1969          4881          5770          4003
# 3        153          2276          2120          1430          1048
# 4       2074         29933         34105         42024         49704
# 5        468          6811          6481          5421          3811
# 6        248          4238          3841          3531          2580
# 7         23           888          1029           957            NaN
# 8        126           253           163           187           116
# 9        286          4656          3307          2591          2032
# 10         9            NaN           NaN           NaN           NaN
# 11       321          8408          9050          7475          7542
# 12       444          9197          8705          7339          5389
# 13       265          6027          5951          5072          4977
# 14       364          2308          2488          2577          2301
# 15       147          2064          1310           987           979
# 16       623          3489          3372          3191          2535
# 17        35            61            89            NaN           66
# 18       345          7633          7293          6341          4989
# 15             470             245
# 16            1251             964
# 17              54              29
# 18            3424            2595
# 19            2363            2064
# 20            4083            3938
# 21           44411           39553
# 22            2618            2950
# 23             115             100
# 24            2920            1819
# 25             327             219
# 26             296             NaN
# 27              97              94
# 28            2190            1912
# 29            2324            1859
# 30            1814            1769
# 31           46994           44916
# 32            7606            6803
# 33             NaN              33
# 34            6714            5296
# 35             165              92
# 36            6658            5562
# 37           23020           20791
# 38             265             354
# 39             901             482
# 40             101             238
# 41            1138            1062
# 42             405             278
# 43            1666            1416
# 44            2825            2806
# 45           16249           12619
# 46          152241          152334
# 47            6365            4424
# 48            5618            5136
# 49             NaN              44

# %% [markdown]
# Remove spaces preceeding the state names

# %%
apple2["State"] = apple2["State"]
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewHampshire', 'NewJersey', 'NewMexico',
#        'NewYork', 'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'RhodeIsland', 'SouthCarolina',
#        'SouthDakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# Convert columns to numeric. Convert to floats instead of integers because NaNs are considered float values.

# %%
 apple2.iloc[:,1:18]=apple2.iloc[:,1:18].astype(float)

apple2.dtypes
# Out:
# 1982_Farms             float64
# 1987_Farms             float64
# 1992_Farms             float64
# 1997_Farms             float64
# 2002_Farms             float64
# 2007_Farms             float64
# 1982_TTLAcres          float64
# 1987_TTLAcres          float64
# 1992_TTLAcres          float64
# 1997_TTLAcres          float64
# 2002_TTLAcres          float64
# 2007_TTLAcres          float64
# 2002_FarmBear_Acres    float64
# 2007_FarmBear_Acres    float64
# 2002_Bear_Acres        float64
# 2007_Bear_Acres        float64
# dtype: object

# %%
apple2["State"]dtypes
# Out:
#   File "/var/folders/1l/syhpq_sj77q6gx1rgkyqgt4c0000gn/T/ipykernel_876/631133532.py", line 1
#     apple2["State"]dtypes
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Check the types to make sure all is good

# %% [markdown]
# Now desribe the numeric data

# %%
apple2.describe
# Out:
# <bound method NDFrame.describe of     1982_Farms  1987_Farms  1992_Farms  1997_Farms  2002_Farms  2007_Farms  \
# 0        899.0       626.0       474.0       479.0       265.0       231.0
# 1          NaN         NaN         2.0         4.0         9.0        10.0
# 2        214.0       224.0       235.0       158.0       185.0       496.0
# 3        512.0       451.0       247.0       238.0       164.0       153.0
# 4       2904.0      2787.0      3082.0      3454.0      2120.0      2074.0
# 5        608.0       595.0       542.0       493.0       361.0       468.0
# 6        309.0       272.0       295.0       242.0       247.0       248.0
# 7         24.0        18.0        16.0        18.0        17.0        23.0
# 8        196.0       149.0        92.0        81.0        53.0       126.0
# 9        893.0       669.0       525.0       428.0       305.0       286.0
# 10         NaN         NaN         NaN         NaN         2.0         9.0
# 11       411.0       377.0       374.0       342.0       315.0       321.0
# 12       902.0       824.0       756.0       651.0       501.0       444.0
# 13       792.0       705.0       685.0       615.0       442.0       265.0
# 14       439.0       458.0       450.0       443.0       344.0       364.0
# 15       416.0       318.0       264.0       261.0       192.0       147.0
# 16      1022.0       916.0       878.0       710.0       616.0       623.0
# 17       122.0       142.0        81.0        94.0        51.0        35.0
#        1997_TTLAcres  2002_TTLAcres  2007_TTLAcres  2002_FarmBear_Acres  \
# count      47.000000      47.000000      47.000000            50.000000
# mean    12927.510638    9863.234043    8470.638298           421.680000
# std     34141.187355   27100.575228   25504.573629           613.202348
# min         2.000000       6.000000      15.000000             2.000000
# 25%       973.500000     596.500000     373.000000           119.250000
# 50%      3187.000000    2384.000000    2057.000000           232.500000
# 75%      6465.500000    4202.500000    3966.000000           400.750000
# max    215463.000000  172810.000000  165215.000000          3580.000000
#
#        2007_FarmBear_Acres  2002_Bear_Acres  2007_Bear_Acres
# count            50.000000        45.000000        47.000000
# mean            434.320000      8917.000000      7651.595745
# std             557.364954     24400.441667     23454.296203
# min               8.000000        19.000000         3.000000
# 25%             116.500000       470.000000       261.500000
# 50%             264.000000      2113.000000      1769.000000
# 75%             453.250000      4083.000000      3444.000000
# max            2912.000000    152241.000000    152334.000000

# %% [markdown]
# Now that we have numeric data we can perform a proper summary

# %%
apple2.isna().sum()
# Out:
# 1982_Farms             2
# 1987_Farms             2
# 1992_Farms             1
# 1997_Farms             1
# 2002_Farms             0
# 2007_Farms             0
# 1982_TTLAcres          2
# 1987_TTLAcres          2
# 1992_TTLAcres          3
# 1997_TTLAcres          3
# 2002_TTLAcres          3
# 2007_TTLAcres          3
# 2002_FarmBear_Acres    0
# 2007_FarmBear_Acres    0
# 2002_Bear_Acres        5
# 2007_Bear_Acres        3
# dtype: int64

# %% [markdown]
# Do we have any missing values?

# %% [markdown]
# Are missing values reasonable?  Should we remove any?

# %% [raw]
# Yes maybe later though, we wont remove anything at this point in time

# %% [markdown]
# Do we have any duplicated data?

# %%
apple2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Does our only categorical column have expected values?

# %%
apple2["state"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/1l/syhpq_sj77q6gx1rgkyqgt4c0000gn/T/ipykernel_876/2443224212.py in <module>
# ----> 1 apple2["state"].unique()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'state'

# %% [markdown]
# How many rows do we have per state?

# %% [markdown]
# Are the number of rows per state what we expect?

# %% [markdown]
# ### Tidy the data

# %% [markdown]
# What is/are the observable unit(s)?

# %% [raw]
# States

# %% [markdown]
# What are the variables?

# %% [raw]
# Year, acerage, bearing acres, number of farms, state

# %% [markdown]
# What are the observations (values)?

# %% [raw]
# numeric year, count of acres, amount of bearing acres, count of farms, state name

# %%
apple2.head()
# Out:
#    1982_Farms  1987_Farms  1992_Farms  1997_Farms  2002_Farms  2007_Farms  \
# 0       899.0       626.0       474.0       479.0       265.0       231.0
# 1         NaN         NaN         2.0         4.0         9.0        10.0
# 2       214.0       224.0       235.0       158.0       185.0       496.0
# 3       512.0       451.0       247.0       238.0       164.0       153.0
# 4      2904.0      2787.0      3082.0      3454.0      2120.0      2074.0
#
#    1982_TTLAcres  1987_TTLAcres  1992_TTLAcres  1997_TTLAcres  2002_TTLAcres  \
# 0         1548.0         1217.0         1011.0          968.0          594.0
# 1            NaN            NaN            NaN            2.0           13.0
# 2         1969.0         4881.0         5770.0         4003.0         1581.0
# 3         2276.0         2120.0         1430.0         1048.0          658.0
# 4        29933.0        34105.0        42024.0        49704.0        38268.0
#
#    2007_TTLAcres  2002_FarmBear_Acres  2007_FarmBear_Acres  2002_Bear_Acres  \
# 0          393.0                191.0                144.0            386.0
# 1           15.0                  8.0                 10.0              NaN
# 2         1344.0                118.0                424.0           1459.0
# 3          287.0                123.0                116.0            560.0
# 4        22184.0               1850.0               1850.0          35856.0
#
#    2007_Bear_Acres
# 0            307.0
# 1              NaN
# 2           1249.0
# 3            220.0
# 4          20954.0

# %% [markdown]
# Next, tidy the data by melting the data. We have multiple variables in the header and we must melt them individually.  The best way to do this is to melt each variable separately, then combine them back to a single data frame.
#
# Do this, you will need to perform multiple melts:
# 1. First melt only the colums that have the number of farms and name the column `Farms`.
# 2. Second, melt only the columns that have the number of acres and name the column `Acres`.
# 3. Third, melt only the columns that have the number of bearing farms and name the column `Bearing_Farms`,
# 4. Fourth, melt only the columns that have the number of bearing acres and name the column `Bearing_Acres`.
#
# You'll also want to remove the prefix (e.g. "Farms-") from each value after melting and convert the 'Year' column to an integer.
#
# For example, after the first melt you should have a dataframe that looks like the following:
#
# |  | State | Year | Farms |
# | - | ----- | ---- | --------- |
# | 0 | Alabama | 1982 | 899 |
# | 1 | Alaska | 1982 | NaN |
# | 2 | Arizona | 1982 | 214 |
# | 3 | Arkansas | 1982 | 512 |
# | 4 | California | 1982 | 2904 |

# %% [markdown]
# Melt #1

# %%
apple_melt1 = pd.melt(apple2, id_vars='State', var_name='Year',
                      value_name='Farms', ignore_index=True)
apple_melt1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/1l/syhpq_sj77q6gx1rgkyqgt4c0000gn/T/ipykernel_876/2370541009.py in <module>
# ----> 1 apple_melt1 = pd.melt(apple2, id_vars='State', var_name='Year',
#       2                       value_name='Farms', ignore_index=True)
#       3 apple_melt1.head()
#       4
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     130     mdata = {}
#     131     for col in id_vars:
# --> 132         id_data = frame.pop(col)
#     133         if is_extension_array_dtype(id_data):
#     134             id_data = concat([id_data] * K, ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in pop(self, item)
#    5271         3  monkey        NaN
#    5272         """
# -> 5273         return super().pop(item=item)
#    5274
#    5275     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in pop(self, item)
#     863
#     864     def pop(self, item: Hashable) -> Series | Any:
# --> 865         result = self[item]
#     866         del self[item]
#     867
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'State'

# %% [markdown]
# Melt #2

# %% [markdown]
# Melt #3

# %% [markdown]
# Melt #4

# %% [markdown]
# Now combine all four melted dataframes into a single dataframe. To do this we can use the [pd.DataFrame.join()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) function. We will need to join one table at a time.
#
# Note: when you join tables they must have the same indexes. So, be sure to set the index of each dataframe before joining by using the [set_index()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html) function.

# %%
# Set the indexes to be the same

# %%
# Join all of the tables.

# %% [markdown]
# What's the shape of the data now?

# %% [markdown]
# Do we have any duplicated rows now?

# %% [markdown]
# Now, do we want to remove missing values?

# %% [markdown]
# ### Explore the Data Again

# %% [markdown]
# Now that we have our data fully cleaned and tidy'ed let's explore it to make sure all looks good. First, we should still have 50 states. Can you find out?

# %% [markdown]
# How many years do we have per state? We should have the same number except for the states where we removed rows with missing values

# %% [markdown]
# Describe the data, but make sure it does so by state.
